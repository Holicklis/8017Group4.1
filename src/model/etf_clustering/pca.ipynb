# %%
import pandas as pd
pd.set_option('display.max_columns', None)

# %%
df = pd.read_excel("/Users/hunglun/Library/Mobile Documents/com~apple~CloudDocs/Study/HKU_STAT/2025_Sem2/STAT8020/Project/8017Group4.1/data/etf/summary/ETP_Data_Export.xlsx")

# %%
import polars as pl
import pandas as pd

# %%
df = pd.read_parquet("/Users/hunglun/Library/Mobile Documents/com~apple~CloudDocs/Study/HKU_STAT/2025_Sem2/STAT8020/Project/8017Group4.1/data/etf/ohlcv/2800/ohlcv.parquet")

# %%
df.columns
# Out:
# Index(['Date', 'Close', 'High', 'Low', 'Open', 'Volume'], dtype='str', name='Price')
